# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pysr
from pysr import PySRRegressor

import sys
import os
import argparse
import glob

from handlers import trainer, evaluation, annealing, sr_trainer
from handlers.args import setup_argparse
from handlers.model_loader import import_module, initialize_models

from ml_utils import losses
from ml_utils import surrogates
from ml_utils.optimizers import optim

from preprocessing.dataloaders import train_load, test_load
from preprocessing.datasets import SimpleIterDataset

from postprocessing.io_writer import _write_outputs_to_root

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import mplhep as mh
plt.style.use(mh.style.CMS)

from importlib.util import spec_from_file_location, module_from_spec

from weaver.utils.logger import _logger, warn_n_times, _configLogger
import copy
from pprint import pformat
import time

from main import assemble_loaders
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
workdir = os.getenv('WORKDIR')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Args:
    def __init__(self, **kwargs):
        # defaults
        self.data_train = []
        self.data_test = []
        self.data_val = []
        self.num_workers = 0
        self.num_epochs = 0
        self.data_config = ''
        self.file_fraction = 1
        self.data_fraction = 1
        self.batch_size = 0
        self.local_rank = None
        self.model_prefix = None
        self.lr_finder = None
        self.optimizer_option = []
        self.optimizer = 'ranger'
        self.start_lr = 1e-3
        self.final_lr = 1e-6
        self.lr_scheduler = 'flat+decay'
        self.kl_weight = 0.1
        self.class_weight = 1.0
        self.kl_anneal = False
        self.alpha = 0
        self.beta = 0
        self.gamma = 0
        self.bit_size = None
        self.dr_path = None
        self.dr_network = None
        
        for key, value in kwargs.items():
            setattr(self, key, value)

# %%
signal = 'TTBar'

yaml_config = f'{workdir}/data_config/JetClass/JetClass_{signal}.yaml'
encoder_network = f'{workdir}/wrappers/vae.py'
sr_path = f'{workdir}/outputs/sr_runs/{signal}/Surrogate/Surrogate_M7-SRPART_ParT_BVAE_SR'
dr_path = f'{workdir}/outputs/models/{signal}/BVAE/BVAE_M6-BVAE_DR_epoch-4_state.pt'

jc_paths = {
    'train': f'{workdir}/datasets/JetClass/Pythia/train_100M',
    'val': f'{workdir}/datasets/JetClass/Pythia/val_5M',
    'test': f'{workdir}/datasets/JetClass/Pythia/test_20M'
}

num_classes = 2
signal_glob = f'/{signal}_*.root'
background = '/ZJetsToNuNu_*.root'

datasets = {}

for name, path in jc_paths.items():

    if isinstance(signal_glob, str):
        signal_files = glob.glob(path+signal_glob)

    if isinstance(background, str):
        background_files = glob.glob(path+background)

    datasets[name] = signal_files + background_files

complexity = {
    'particle_attn': 2,
    'class_attn': 1
}

# %%
args = Args(
    data_train = datasets['train'],
    data_val = datasets['val'],
    data_test = datasets['test'],
    data_config = yaml_config,
    num_epochs = 5,
    batch_size = 64,
    model_prefix = 'throaway_folder/VAE',
    file_fraction = 1,
    data_fraction = 0.005,
    dr_network = encoder_network,
    kl_anneal = True,
    alpha=0,
    beta=4,
    gamma=0,
    bit_size=0.4,
    dr_path = dr_path,
)

# %%
vae_dict = initialize_models(training=False, network=args.dr_network, data_config=args.data_config, model_path=args.dr_path)
loader_dict = assemble_loaders(args)

dr = copy.deepcopy(vae_dict['model']).to(device)

# %%
vae_loss = losses.BVAELoss(
    beta=args.beta,
    bit=args.bit_size
)

recon_loss = losses.ChamferDist()

vae_tester=evaluation.BVAEStats(
    vae_loss=vae_loss,
    recon_loss=recon_loss,
    model=dr,
    device=device,
    loader=loader_dict['test'],
    split='test'
)

# %%
with torch.no_grad():
    test_dict = vae_tester.run()
# Out:
# 0it [00:00, ?it/s]
# === Restarting DataIter test_, seed=None ===
# 313it [00:38,  8.07it/s, Loss=15.96609, KLD=3.86943, Recon Loss=0.48835, Beta=4.00, AvgKLD=4.06501, AvgReconLoss=0.43905, Avg Loss=16.69908]

# %%
dim = 1

tradim = test_dict['interpretability']['latent_traversals'][f'dim_{dim}']

# %%
import matplotlib.colors as mcolors

#fig, axes = plt.subplots(ncols=7, nrows=5, figsize=(12, 9))
fig = plt.figure(figsize=(12, 9))
gs = fig.add_gridspec(5, 7)

norm=mcolors.Normalize(vmin=0, vmax=3)

im = None

latent_plot = fig.add_subplot(gs[:, :])
latent_plot.set(xlim=(-3, 3), ylabel=None)
latent_plot.tick_params(labelleft=False, axis='both', which='both', top=False, left=False, right=False, bottom=False)
latent_plot.spines['top'].set_visible(False)   
latent_plot.spines['right'].set_visible(False) 
latent_plot.spines['left'].set_visible(False)
latent_plot.spines['bottom'].set_visible(False)

for n_mag, mag in enumerate(tradim['sig']):
    for n_sample, sample in enumerate(mag):
        deta = sample[5].flatten()
        dphi = sample[6].flatten()
        e_log = sample[1].flatten()
        pt_log = sample[0].flatten()
        #ax = axes[n_sample, n_mag]
        ax = fig.add_subplot(gs[n_sample, n_mag])
        ax.set(xlabel=None, ylabel=None)
        ax.tick_params(labelbottom=False, labelleft=False)
        ax.set(xlim=(-10, 10), ylim=(-10, 10))
        h, xedges, yedges, im = ax.hist2d(dphi, deta, bins=[30, 30], norm=norm, range=[[-0.005, 0.005], [-0.05, 0.05]], cmap='inferno', weights=e_log)

fig.suptitle(rf'$z_{{{dim}}}$ (WToQQ)', y=0.94)

fig.colorbar(mappable=im, ax=fig.get_axes(), fraction=.05)

plt.show()

# %%
fig, axes = plt.subplots(ncols=7, nrows=5, figsize=(12, 9))

for row, col in enumerate(axes):
    for ax in col:
        ax.set(xlabel=None, ylabel=None)
        ax.set_xticklabels([])
        ax.set_yticklabels([])

for n_mag, mag in enumerate(tradim['sig']):
    for n_sample, sample in enumerate(mag):
        pt_log = sample[0].flatten()
        ax = axes[n_sample, n_mag]
        ax.set_xlim(0, 6)
        ax.hist(pt_log, bins = 32)

fig.suptitle(r'$z_5$')

plt.show()

# %%
fig, axes = plt.subplots(ncols=7, nrows=5, figsize=(12, 9))

for row, col in enumerate(axes):
    for ax in col:
        ax.set(xlabel=None, ylabel=None)
        ax.set_xticklabels([])
        ax.set_yticklabels([])

for n_mag, mag in enumerate(dim_0['bkg']):
    for n_sample, sample in enumerate(mag):
        e_log = sample[1].flatten()
        ax = axes[n_sample, n_mag]
        ax.set_xlim(0, 6)
        ax.hist(e_log, bins = 32)

fig.suptitle(r'$z_0$')

plt.show()
